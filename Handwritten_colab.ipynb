# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya210504/Digital-Handwritten-Recognition/blob/main/Handwritten_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import numpy as np
import struct
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import sys  #  For program termination

#  Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

#  Function to read IDX image files
def read_idx(filename):
    with open(filename, 'rb') as f:
        _, num, rows, cols = struct.unpack('>IIII', f.read(16))
        data = np.frombuffer(f.read(), dtype=np.uint8).reshape(num, rows, cols)
    return data

#  Function to read IDX label files
def read_labels(filename):
    with open(filename, 'rb') as f:
        _,num = struct.unpack('>II', f.read(8))
        labels = np.frombuffer(f.read(), dtype=np.uint8)
        return labels

#  Load dataset
train_images = read_idx(r'C:\Users\Admin\Downloads\Handwritten\train-images.idx3-ubyte')
train_labels = read_labels(r'C:\Users\Admin\Downloads\Handwritten\train-labels.idx1-ubyte')
test_images  = read_idx(r'C:\Users\Admin\Downloads\Handwritten\t10k-images.idx3-ubyte')
test_labels  = read_labels(r'C:\Users\Admin\Downloads\Handwritten\t10k-labels.idx1-ubyte')

#  Visualizing some images
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(train_images[i], cmap='gray')
    plt.title(f'Label: {train_labels[i]}')
    plt.axis('off')

plt.show()

#  Terminate the program if you close the window
if not plt.fignum_exists(1):
    print("Output window closed. Terminating program...")
    sys.exit()

#  Custom Dataset Class with PIL conversion
class MNISTDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]

        #  Convert NumPy array to PIL image
        image = Image.fromarray(image)

        if self.transform:
            image = self.transform(image)

        return image, label

#  Define transformations
transform = transforms.Compose([
    transforms.Resize((20, 20)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

#  Create DataLoader
train_dataset = MNISTDataset(train_images, train_labels, transform=transform)
test_dataset = MNISTDataset(test_images, test_labels, transform=transform)

train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, shuffle=False)

#  Define CNN Model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

#  Model Initialization
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

#  Training Loop
epochs = 3
for epoch in range(epochs):
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss:.4f}")
# Out:
# Using device: cpu
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1-4188921933.py in <cell line: 0>()
#      29
#      30 #  Load dataset
# ---> 31 train_images = read_idx(r'C:\Users\Admin\Downloads\Handwritten\train-images.idx3-ubyte')
#      32 train_labels = read_labels(r'C:\Users\Admin\Downloads\Handwritten\train-labels.idx1-ubyte')
#      33 test_images  = read_idx(r'C:\Users\Admin\Downloads\Handwritten\t10k-images.idx3-ubyte')
#
# /tmp/ipython-input-1-4188921933.py in read_idx(filename)
#      16 #  Function to read IDX image files
#      17 def read_idx(filename):
# ---> 18     with open(filename, 'rb') as f:
#      19         _, num, rows, cols = struct.unpack('>IIII', f.read(16))
#      20         data = np.frombuffer(f.read(), dtype=np.uint8).reshape(num, rows, cols)
#
# ...
